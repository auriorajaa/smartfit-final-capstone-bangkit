# %% [markdown]
# **DATA CLEANING**

# %% [markdown]
# Import Packages

# %%
from PIL import Image
import os
import hashlib
import numpy as np
from google.colab import drive

# %%
# Mounting Google Drive in Colab
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# LIGHT SUBDIRECTORIES

# %% [markdown]
# Checking for Corrupted or Invalid Images

# %%
# The directory where the image is stored
image_directory = '/content/drive/My Drive/Capstone/data_skintone/light'

# Creating a list to save corrupted image paths
invalid_images = []

# Loop to check images one by one
for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        image_path = os.path.join(image_directory, filename)
        try:
            img = Image.open(image_path)
            img.verify()  # Verifying images
        except (IOError, SyntaxError) as e:
            print(f"Corrupted or invalid images: {image_path}")
            invalid_images.append(image_path)

# Remove corrupted images from directories
for invalid_image in invalid_images:
    os.remove(invalid_image)
    print(f"File {invalid_image} has been deleted.")

# %% [markdown]
# Removing Duplicate Images

# %%
# Functions for calculating image hashes
def calculate_image_hash(image_path):
    with Image.open(image_path) as img:
        img = img.resize((100, 100)).convert("L")  # Resize and convert to grayscale for accuracy
        hash_val = hashlib.md5(img.tobytes()).hexdigest()  # Calculating the hash of an image
    return hash_val

# Detect and remove duplicate images
hashes = {}
duplicate_images = []

for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        image_path = os.path.join(image_directory, filename)
        image_hash = calculate_image_hash(image_path)

        if image_hash in hashes:
            print(f"Duplicate image found: {image_path} duplicate of {hashes[image_hash]}")
            duplicate_images.append(image_path)
        else:
            hashes[image_hash] = image_path

# Remove duplicate images from directories
for duplicate_image in duplicate_images:
    os.remove(duplicate_image)
    print(f"Duplicate files {duplicate_image} has been deleted.")
# Out:
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/light/88974939.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/light/87177968.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/light/48774375.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/light/54283817.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/light/40820641.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/light/40710202.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/light/42377315.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/light/58632360.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/light/42377341.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/light/58632343.jpg
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/light/88974939.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/light/48774375.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/light/40820641.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/light/42377315.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/light/42377341.jpg has been deleted.

# %% [markdown]
# Checking Image Size and Resolution

# %%
# Check the size of images and make a list of images that are too small
min_size = (100, 100)  # Minimum allowable size

small_images = []

for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        image_path = os.path.join(image_directory, filename)
        with Image.open(image_path) as img:
            if img.size[0] < min_size[0] or img.size[1] < min_size[1]:
                print(f"Image too small: {image_path}, size: {img.size}")
                small_images.append(image_path)

# Remove images that are too small
for small_image in small_images:
    os.remove(small_image)
    print(f"File {small_image} has been removed because it is too small in size.")

# %% [markdown]
# Normalizing Images

# %%
# Function to normalize images
def normalize_image(image_path, target_size=(224, 224)):
    img = Image.open(image_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img) / 255.0  # Normalization
    return img_array

# Example normalization for a single image
sample_image = normalize_image(os.path.join(image_directory, '358609.jpg'))
print("Sample image shape:", sample_image.shape)
# Out:
# Sample image shape: (224, 224, 3)

# %% [markdown]
# MID-LIGHT SUBDIRECTIORIES

# %% [markdown]
# Checking for Corrupted or Invalid Images

# %%
# The directory where the image is stored
image_directory = '/content/drive/My Drive/Capstone/data_skintone/mid-light'

# Creating a list to save corrupted image paths
invalid_images = []

# Loop to check images one by one
for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        image_path = os.path.join(image_directory, filename)
        try:
            img = Image.open(image_path)
            img.verify()  # Verifying images
        except (IOError, SyntaxError) as e:
            print(f"Corrupted or invalid images: {image_path}")
            invalid_images.append(image_path)

# Remove corrupted images from directories
for invalid_image in invalid_images:
    os.remove(invalid_image)
    print(f"File {invalid_image} has been deleted.")

# %% [markdown]
# Removing Duplicate Images

# %%
# Functions for calculating image hashes
def calculate_image_hash(image_path):
    with Image.open(image_path) as img:
        img = img.resize((100, 100)).convert("L")  # Resize and convert to grayscale for accuracy
        hash_val = hashlib.md5(img.tobytes()).hexdigest()  # Calculating the hash of an image
    return hash_val

# Detect and remove duplicate images
hashes = {}
duplicate_images = []

for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        image_path = os.path.join(image_directory, filename)
        image_hash = calculate_image_hash(image_path)

        if image_hash in hashes:
            print(f"Duplicate image found: {image_path} duplicate of {hashes[image_hash]}")
            duplicate_images.append(image_path)
        else:
            hashes[image_hash] = image_path

# Remove duplicate images from directories
for duplicate_image in duplicate_images:
    os.remove(duplicate_image)
    print(f"Duplicate files {duplicate_image} has been deleted.")
# Out:
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1005.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1005.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10157.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10157.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10209.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10209.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10383.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10383.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10395.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10395.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1041.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1041.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10425.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10425.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10459.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10459.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1068.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1068.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_10703.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_10703.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1077.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1077.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1173.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1173.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1229.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1229.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1305.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1305.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1362.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1362.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1372.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1372.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1406.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1406.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1408.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1408.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1431.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1431.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1455.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1455.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1553.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1553.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1723.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1723.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1743.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1743.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1754.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1754.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1841.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1841.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1849.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1849.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1923.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1923.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1935.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1935.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1946.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1946.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1954.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1954.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1959.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1959.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_1982.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_1982.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2036.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2036.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2041.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2041.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_215.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_215.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2166.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2166.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_219.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_219.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2280.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2280.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2311.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2311.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2350.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2350.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2385.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2385.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2386.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2386.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2402.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2402.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2458.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2458.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2530.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2530.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2536.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2536.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2605.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2605.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2633.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2633.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2640.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2640.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2696.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2696.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2713.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2713.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2810.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2810.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2834.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2834.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2868.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2868.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_2957.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_2957.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_298.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_298.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3040.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3040.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3095.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3095.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3096.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3096.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3119.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3119.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3190.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3190.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3207.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3207.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3243.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3243.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3246.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3246.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3266.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3266.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3283.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3283.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3292.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3292.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_33.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_33.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3306.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3306.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3391.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3391.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3394.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3394.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3514.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3514.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3528.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3528.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3577.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_3577.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/image_3607.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_image_
jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_94051975.jpg
# Duplicate image found: /content/drive/My Drive/Capstone/data_skintone/mid-light/9417243.jpg duplicate of /content/drive/My Drive/Capstone/data_skintone/mid-light/augmented_9417243.jpg
# ...
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41613564.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41770345.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41771539.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41773898.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41937550.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41947165.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/41981645.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42098622.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42112895.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42136096.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42141801.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4216221.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42177222.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42199719.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42201497.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42265041.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42293613.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42299230.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42312850.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42315442.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42357599.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42358184.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42365184.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42380952.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42435205.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42436970.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42476041.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42509134.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42816913.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42934303.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/42982017.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43019622.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43123502.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43194329.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43314112.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43423097.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43443054.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43476428.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43584043.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43650888.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43690378.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43719818.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43739624.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43807858.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43832203.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43886874.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43910044.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/43996740.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44153768.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44196816.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44250465.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44413396.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4445731.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4446276.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4471739.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44734246.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44821451.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44836261.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44855764.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/44860084.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45020512.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45100696.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45100697.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45161840.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4525786.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4531541.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45384532.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45564258.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45572560.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45587934.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45589009.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45590405.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45625098.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45691320.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45704061.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/45879495.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46025943.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46029968.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46125354.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46315777.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46331028.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46389140.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46436222.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46442074.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46569919.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46574024.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46587432.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46665625.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46744997.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46764615.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46784190.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46886640.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/46936537.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47103211.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47175978.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47184824.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47224050.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47246223.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47248823.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47299647.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47356713.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47393548.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47532299.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47654254.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47782530.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47834728.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47842437.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47871877.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47924781.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/47993988.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48126741.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48191426.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48230892.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48231034.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48267763.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48285289.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48303528.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48360080.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/4837972.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48455040.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48655647.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48764588.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48770194.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48806616.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48844116.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/48884023.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49012426.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49029588.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49078652.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49084345.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49135457.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49174119.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49226388.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49333897.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49389109.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49516102.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49535661.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49599699.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49601989.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49672975.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49865128.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49880848.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49976984.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49978720.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/49999326.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50056226.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50070273.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50071960.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50072008.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/5014756.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50225464.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50249694.jpg has been deleted.
# Duplicate files /content/drive/My Drive/Capstone/data_skintone/mid-light/50277112.jpg has been deleted.

# %% [markdown]
# Checking Image Size and Resolution

# %%
# Check the size of images and make a list of images that are too small
min_size = (100, 100)  # Minimum allowable size

small_images = []

for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        image_path = os.path.join(image_directory, filename)
        with Image.open(image_path) as img:
            if img.size[0] < min_size[0] or img.size[1] < min_size[1]:
                print(f"Image too small: {image_path}, size: {img.size}")
                small_images.append(image_path)

# Remove images that are too small
for small_image in small_images:
    os.remove(small_image)
    print(f"File {small_image} has been removed because it is too small in size.")

# %% [markdown]
# Normalizing Images

# %%
# Function to normalize images
def normalize_image(image_path, target_size=(224, 224)):
    img = Image.open(image_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img) / 255.0  # Normalization
    return img_array

# Example normalization for a single image
sample_image = normalize_image(os.path.join(image_directory, '85407.jpg'))
print("Sample image shape:", sample_image.shape)
# Out:
# Sample image shape: (224, 224, 3)
